# %% [markdown]
# # Classic Monty Hall Bayesian Network

# %% [markdown]
# authors:<br>
# Jacob Schreiber [<a href="mailto:jmschreiber91@gmail.com">jmschreiber91@gmail.com</a>]<br>
# Nicholas Farn [<a href="mailto:nicholasfarn@gmail.com">nicholasfarn@gmail.com</a>]

# %% [markdown]
# Lets test out the Bayesian Network framework to produce the Monty Hall problem, but modified a little. The Monty Hall problem is basically a game show where a guest chooses one of three doors to open, with an unknown one having a prize behind it. Monty then opens another non-chosen door without a prize behind it, and asks the guest if they would like to change their answer. Many people were surprised to find that if the guest changed their answer, there was a 66% chance of success as opposed to a 50% as might be expected if there were two doors.
#
# This can be modelled as a Bayesian network with three nodes-- guest, prize, and Monty, each over the domain of door 'A', 'B', 'C'. Monty is dependent on both guest and prize, in that it can't be either of them. Lets extend this a little bit to say the guest has an untrustworthy friend whose answer he will not go with.

# %%
# !c:\Users\fatib\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip
# %pip install pomegranate==0.14.5
# Out:
# Requirement already satisfied: pip in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (22.3)
# Collecting pomegranate==0.13.5
#   Downloading pomegranate-0.13.5.tar.gz (4.5 MB)
#      ---------------------------------------- 4.5/4.5 MB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.8.0 in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (from pomegranate==0.13.5) (1.20.3)
# Requirement already satisfied: joblib>=0.9.0b4 in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (from pomegranate==0.13.5) (1.1.0)
# Requirement already satisfied: networkx>=2.0 in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (from pomegranate==0.13.5) (2.8.7)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (from pomegranate==0.13.5) (1.7.1)
# Requirement already satisfied: pyyaml in c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages (from pomegranate==0.13.5) (5.4.1)
# Building wheels for collected packages: pomegranate
#   Building wheel for pomegranate (setup.py): started
#   Building wheel for pomegranate (setup.py): finished with status 'error'
#   Running setup.py clean for pomegranate
# Failed to build pomegranate
# Installing collected packages: pomegranate
#   Attempting uninstall: pomegranate
#     Found existing installation: pomegranate 0.14.0
#     Uninstalling pomegranate-0.14.0:
#       Successfully uninstalled pomegranate-0.14.0
#   Running setup.py install for pomegranate: started
#   Running setup.py install for pomegranate: finished with status 'error'
#   Rolling back uninstall of pomegranate
#   Moving to c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages\pomegranate-0.14.0.dist-info\
#    from C:\Users\fatib\AppData\Local\Programs\Python\Python39\Lib\site-packages\~omegranate-0.14.0.dist-info
#   Moving to c:\users\fatib\appdata\local\programs\python\python39\lib\site-packages\pomegranate\
#    from C:\Users\fatib\AppData\Local\Programs\Python\Python39\Lib\site-packages\~-megranate
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [500 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-3.9
#       creating build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\callbacks.py -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\io.py -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\__init__.py -> build\lib.win-amd64-3.9\pomegranate
#       creating build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate/distributions\NeuralNetworkWrapper.py -> build\lib.win-amd64-3.9\pomegranate/distributions
#       copying pomegranate/distributions\__init__.py -> build\lib.win-amd64-3.9\pomegranate/distributions
#       running egg_info
#       writing pomegranate.egg-info\PKG-INFO
#       writing dependency_links to pomegranate.egg-info\dependency_links.txt
#       writing requirements to pomegranate.egg-info\requires.txt
#       writing top-level names to pomegranate.egg-info\top_level.txt
#       adding license file 'LICENSE' (matched pattern 'LICEN[CS]E*')
#       reading manifest file 'pomegranate.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       writing manifest file 'pomegranate.egg-info\SOURCES.txt'
#       copying pomegranate\BayesClassifier.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\BayesClassifier.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\BayesianNetwork.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\BayesianNetwork.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\FactorGraph.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\FactorGraph.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\MarkovChain.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\MarkovChain.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\MarkovNetwork.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\MarkovNetwork.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\NaiveBayes.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\NaiveBayes.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\base.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\base.pxd -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\base.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\bayes.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\bayes.pxd -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\bayes.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\gmm.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\gmm.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\hmm.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\hmm.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\kmeans.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\kmeans.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\parallel.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\parallel.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\utils.c -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\utils.pxd -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\utils.pyx -> build\lib.win-amd64-3.9\pomegranate
#       copying pomegranate\distributions\BernoulliDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\BernoulliDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\BernoulliDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\BetaDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\BetaDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\BetaDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ConditionalProbabilityTable.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ConditionalProbabilityTable.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ConditionalProbabilityTable.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DirichletDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DirichletDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DirichletDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DiscreteDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DiscreteDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\DiscreteDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ExponentialDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ExponentialDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\ExponentialDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\GammaDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\GammaDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\GammaDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\IndependentComponentsDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\IndependentComponentsDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\IndependentComponentsDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\JointProbabilityTable.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\JointProbabilityTable.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\JointProbabilityTable.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\KernelDensities.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\KernelDensities.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\KernelDensities.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\LogNormalDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\LogNormalDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\LogNormalDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\MultivariateGaussianDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\MultivariateGaussianDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\MultivariateGaussianDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\NormalDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\NormalDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\NormalDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\PoissonDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\PoissonDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\PoissonDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\UniformDistribution.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\UniformDistribution.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\UniformDistribution.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\distributions.c -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\distributions.pxd -> build\lib.win-amd64-3.9\pomegranate\distributions
#       copying pomegranate\distributions\distributions.pyx -> build\lib.win-amd64-3.9\pomegranate\distributions
#       running build_ext
#       building 'pomegranate.base' extension
#       creating build\temp.win-amd64-3.9
#       creating build\temp.win-amd64-3.9\Release
#       creating build\temp.win-amd64-3.9\Release\pomegranate
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/base.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/base.obj
#       base.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/base.c(28573): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/base.c(28589): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/base.c(29457): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_base build\temp.win-amd64-3.9\Release\pomegranate/base.obj /OUT:build\lib.win-amd64-3.9\pomegranate\base.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\base.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\base.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\base.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.bayes' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/bayes.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/bayes.obj
#       bayes.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/bayes.c(3443): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(5628): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(7962): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(7963): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(8086): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(8290): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(9561): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(9562): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(9685): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(9879): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/bayes.c(34028): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/bayes.c(34044): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/bayes.c(35608): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_bayes build\temp.win-amd64-3.9\Release\pomegranate/bayes.obj /OUT:build\lib.win-amd64-3.9\pomegranate\bayes.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\bayes.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\bayes.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\bayes.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.BayesianNetwork' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/BayesianNetwork.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/BayesianNetwork.obj
#       BayesianNetwork.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/BayesianNetwork.c(8039): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(9752): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(16997): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(20923): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(20924): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(28185): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(29519): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(29520): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(42906): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(42907): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(43208): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(43985): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(43986): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/BayesianNetwork.c(68916): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/BayesianNetwork.c(68932): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/BayesianNetwork.c(72149): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_BayesianNetwork build\temp.win-amd64-3.9\Release\pomegranate/BayesianNetwork.obj /OUT:build\lib.win-amd64-3.9\pomegranate\BayesianNetwork.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\BayesianNetwork.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\BayesianNetwork.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\BayesianNetwork.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.MarkovNetwork' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/MarkovNetwork.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/MarkovNetwork.obj
#       MarkovNetwork.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/MarkovNetwork.c(3659): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/MarkovNetwork.c(5237): warning C4244: '=': conversÆo de 'double' para 'float', poss¡vel perda de dados
#       pomegranate/MarkovNetwork.c(12667): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/MarkovNetwork.c(12668): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/MarkovNetwork.c(32351): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/MarkovNetwork.c(32367): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/MarkovNetwork.c(34048): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_MarkovNetwork build\temp.win-amd64-3.9\Release\pomegranate/MarkovNetwork.obj /OUT:build\lib.win-amd64-3.9\pomegranate\MarkovNetwork.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\MarkovNetwork.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\MarkovNetwork.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\MarkovNetwork.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.FactorGraph' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/FactorGraph.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/FactorGraph.obj
#       FactorGraph.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/FactorGraph.c(11207): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/FactorGraph.c(11223): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_FactorGraph build\temp.win-amd64-3.9\Release\pomegranate/FactorGraph.obj /OUT:build\lib.win-amd64-3.9\pomegranate\FactorGraph.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\FactorGraph.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\FactorGraph.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\FactorGraph.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.hmm' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/hmm.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/hmm.obj
#       hmm.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/hmm.c(14345): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(16217): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(18582): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(19636): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(20178): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(20187): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(21520): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(21529): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(23137): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(23146): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(23337): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(24148): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(24157): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(25863): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(25872): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(27206): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(27208): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(32660): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(33833): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(33842): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(34229): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(34238): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(35430): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/hmm.c(63326): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/hmm.c(63342): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/hmm.c(65924): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_hmm build\temp.win-amd64-3.9\Release\pomegranate/hmm.obj /OUT:build\lib.win-amd64-3.9\pomegranate\hmm.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\hmm.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\hmm.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\hmm.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.gmm' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/gmm.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/gmm.obj
#       gmm.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/gmm.c(5349): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/gmm.c(5434): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/gmm.c(5836): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/gmm.c(26842): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/gmm.c(26858): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/gmm.c(28578): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_gmm build\temp.win-amd64-3.9\Release\pomegranate/gmm.obj /OUT:build\lib.win-amd64-3.9\pomegranate\gmm.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\gmm.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\gmm.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\gmm.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.kmeans' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/kmeans.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/kmeans.obj
#       kmeans.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/kmeans.c(3263): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(3264): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(4426): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(4526): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(5173): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(6204): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(9933): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(9934): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
#       pomegranate/kmeans.c(31487): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/kmeans.c(31503): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/kmeans.c(32130): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_kmeans build\temp.win-amd64-3.9\Release\pomegranate/kmeans.obj /OUT:build\lib.win-amd64-3.9\pomegranate\kmeans.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\kmeans.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\kmeans.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\kmeans.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.NaiveBayes' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/NaiveBayes.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/NaiveBayes.obj
#       NaiveBayes.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/NaiveBayes.c(7685): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/NaiveBayes.c(7701): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_NaiveBayes build\temp.win-amd64-3.9\Release\pomegranate/NaiveBayes.obj /OUT:build\lib.win-amd64-3.9\pomegranate\NaiveBayes.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\NaiveBayes.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\NaiveBayes.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\NaiveBayes.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.BayesClassifier' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/BayesClassifier.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/BayesClassifier.obj
#       BayesClassifier.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/BayesClassifier.c(7903): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/BayesClassifier.c(7919): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_BayesClassifier build\temp.win-amd64-3.9\Release\pomegranate/BayesClassifier.obj /OUT:build\lib.win-amd64-3.9\pomegranate\BayesClassifier.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\BayesClassifier.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\BayesClassifier.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\BayesClassifier.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.MarkovChain' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/MarkovChain.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/MarkovChain.obj
#       MarkovChain.c
#       pomegranate/MarkovChain.c(1473): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/MarkovChain.c(5946): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/MarkovChain.c(5962): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_MarkovChain build\temp.win-amd64-3.9\Release\pomegranate/MarkovChain.obj /OUT:build\lib.win-amd64-3.9\pomegranate\MarkovChain.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate\MarkovChain.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate\MarkovChain.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate\MarkovChain.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.utils' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/utils.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/utils.obj
#       utils.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/utils.c(5012): warning C4244: '=': conversÆo de 'npy_intp' para 'int', poss¡vel perda de dados
# ...
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate/distributions\IndependentComponentsDistribution.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate/distributions\IndependentComponentsDistribution.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.distributions.MultivariateGaussianDistribution' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/distributions/MultivariateGaussianDistribution.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/distributions/MultivariateGaussianDistribution.obj
#       MultivariateGaussianDistribution.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/distributions/MultivariateGaussianDistribution.c(25932): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/MultivariateGaussianDistribution.c(25948): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/MultivariateGaussianDistribution.c(26907): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_MultivariateGaussianDistribution build\temp.win-amd64-3.9\Release\pomegranate/distributions/MultivariateGaussianDistribution.obj /OUT:build\lib.win-amd64-3.9\pomegranate\distributions\MultivariateGaussianDistribution.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate/distributions\MultivariateGaussianDistribution.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate/distributions\MultivariateGaussianDistribution.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate/distributions\MultivariateGaussianDistribution.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.distributions.DirichletDistribution' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/distributions/DirichletDistribution.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/distributions/DirichletDistribution.obj
#       DirichletDistribution.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/distributions/DirichletDistribution.c(3103): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/DirichletDistribution.c(22583): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/DirichletDistribution.c(22599): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/DirichletDistribution.c(23518): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_DirichletDistribution build\temp.win-amd64-3.9\Release\pomegranate/distributions/DirichletDistribution.obj /OUT:build\lib.win-amd64-3.9\pomegranate\distributions\DirichletDistribution.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate/distributions\DirichletDistribution.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate/distributions\DirichletDistribution.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate/distributions\DirichletDistribution.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.distributions.ConditionalProbabilityTable' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/distributions/ConditionalProbabilityTable.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/distributions/ConditionalProbabilityTable.obj
#       ConditionalProbabilityTable.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/distributions/ConditionalProbabilityTable.c(3542): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/ConditionalProbabilityTable.c(3555): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/ConditionalProbabilityTable.c(3575): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/ConditionalProbabilityTable.c(8697): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/ConditionalProbabilityTable.c(30423): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/ConditionalProbabilityTable.c(30439): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/ConditionalProbabilityTable.c(32489): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_ConditionalProbabilityTable build\temp.win-amd64-3.9\Release\pomegranate/distributions/ConditionalProbabilityTable.obj /OUT:build\lib.win-amd64-3.9\pomegranate\distributions\ConditionalProbabilityTable.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate/distributions\ConditionalProbabilityTable.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate/distributions\ConditionalProbabilityTable.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate/distributions\ConditionalProbabilityTable.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.distributions.JointProbabilityTable' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/distributions/JointProbabilityTable.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/distributions/JointProbabilityTable.obj
#       JointProbabilityTable.c
#       c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       pomegranate/distributions/JointProbabilityTable.c(3681): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(3701): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(3714): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(3734): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(4029): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(7454): warning C4244: '=': conversÆo de 'Py_ssize_t' para 'int', poss¡vel perda de dados
#       pomegranate/distributions/JointProbabilityTable.c(29164): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/JointProbabilityTable.c(29180): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#       pomegranate/distributions/JointProbabilityTable.c(31249): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\libs /LIBPATH:c:\Users\fatib\AppData\Local\Programs\Python\Python39\PCbuild\amd64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64 /EXPORT:PyInit_JointProbabilityTable build\temp.win-amd64-3.9\Release\pomegranate/distributions/JointProbabilityTable.obj /OUT:build\lib.win-amd64-3.9\pomegranate\distributions\JointProbabilityTable.cp39-win_amd64.pyd /IMPLIB:build\temp.win-amd64-3.9\Release\pomegranate/distributions\JointProbabilityTable.cp39-win_amd64.lib
#          Criando biblioteca build\temp.win-amd64-3.9\Release\pomegranate/distributions\JointProbabilityTable.cp39-win_amd64.lib e objeto build\temp.win-amd64-3.9\Release\pomegranate/distributions\JointProbabilityTable.cp39-win_amd64.exp
#       Gerando c¢digo
#       Finalizada a gera‡Æo de c¢digo
#       building 'pomegranate.distributions.NeuralNetworkWrapper' extension
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\include -Ic:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /Tcpomegranate/distributions/NeuralNetworkWrapper.c /Fobuild\temp.win-amd64-3.9\Release\pomegranate/distributions/NeuralNetworkWrapper.obj
#       NeuralNetworkWrapper.c
#       c1: fatal error C1083: NÆo ‚ poss¡vel abrir arquivo fonte: 'pomegranate/distributions/NeuralNetworkWrapper.c': No such file or directory
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pomegranate
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import math
from pomegranate import *
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-15292b3d47e2> in <module>
#       1 import math
# ----> 2 from pomegranate import *
#
# c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\pomegranate\__init__.py in <module>
#       9 import os
#      10
# ---> 11 from .base import *
#      12 from .parallel import *
#      13
#
# c:\Users\fatib\AppData\Local\Programs\Python\Python39\lib\site-packages\pomegranate\base.pyx in init pomegranate.base()
#
# ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %% [markdown]
# Let's create the distributions for the guest and the prize. Note that both distributions are independent of one another.

# %%
guest = DiscreteDistribution( { 'A': 1./3, 'B': 1./3, 'C': 1./3 } )
prize = DiscreteDistribution( { 'A': 1./3, 'B': 1./3, 'C': 1./3 } )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-babf76e88423> in <module>
# ----> 1 guest = DiscreteDistribution( { 'A': 1./3, 'B': 1./3, 'C': 1./3 } )
#       2 prize = DiscreteDistribution( { 'A': 1./3, 'B': 1./3, 'C': 1./3 } )
#
# NameError: name 'DiscreteDistribution' is not defined

# %% [markdown]
# Now let's create the conditional probability table for our Monty. The table is dependent on both the guest and the prize.

# %%
monty = ConditionalProbabilityTable(
	[[ 'A', 'A', 'A', 0.0 ],
	 [ 'A', 'A', 'B', 0.5 ],
	 [ 'A', 'A', 'C', 0.5 ],
	 [ 'A', 'B', 'A', 0.0 ],
	 [ 'A', 'B', 'B', 0.0 ],
	 [ 'A', 'B', 'C', 1.0 ],
	 [ 'A', 'C', 'A', 0.0 ],
	 [ 'A', 'C', 'B', 1.0 ],
	 [ 'A', 'C', 'C', 0.0 ],
	 [ 'B', 'A', 'A', 0.0 ],
	 [ 'B', 'A', 'B', 0.0 ],
	 [ 'B', 'A', 'C', 1.0 ],
	 [ 'B', 'B', 'A', 0.5 ],
	 [ 'B', 'B', 'B', 0.0 ],
	 [ 'B', 'B', 'C', 0.5 ],
	 [ 'B', 'C', 'A', 1.0 ],
	 [ 'B', 'C', 'B', 0.0 ],
	 [ 'B', 'C', 'C', 0.0 ],
	 [ 'C', 'A', 'A', 0.0 ],
	 [ 'C', 'A', 'B', 1.0 ],
	 [ 'C', 'A', 'C', 0.0 ],
	 [ 'C', 'B', 'A', 1.0 ],
	 [ 'C', 'B', 'B', 0.0 ],
	 [ 'C', 'B', 'C', 0.0 ],
	 [ 'C', 'C', 'A', 0.5 ],
	 [ 'C', 'C', 'B', 0.5 ],
	 [ 'C', 'C', 'C', 0.0 ]], [guest, prize] )
guest1 = ConditionalProbabilityTable(
	[[ 'A', 'A', 0.0 ],
	 [ 'A', 'B', 0.5 ],
	 [ 'A', 'C', 0.5 ],
	 [ 'B', 'A', 0.5 ],
	 [ 'B', 'B', 0.0 ],
	 [ 'B', 'C', 0.5 ],
	 [ 'C', 'A', 0.5 ],
	 [ 'C', 'B', 0.5 ],
	 [ 'C', 'C', 0.0 ]], [monty] )

# %% [markdown]
# Now lets create the states for the bayesian network.

# %%
s1 = State( guest, name="guest" )
s2 = State( prize, name="prize" )
s3 = State( monty, name="monty" )
s4 = State( guest1, name="guest1" )

# %% [markdown]
# Then the bayesian network itself, adding the states in after.

# %%
network = BayesianNetwork( "test" )
network.add_states( s1, s2, s3, s4 )

# %% [markdown]
# Then the transitions.

# %%
network.add_transition( s1, s3 )
network.add_transition( s2, s3 )
network.add_transition( s3, s4 )

# %% [markdown]
# With a "bake" to finalize the structure of our network.

# %%
network.bake()

# %% [markdown]
# Now we can check the possible states in our network.

# %%
print("\t".join([ state.name for state in network.states ]))
# Out:
# guest	prize	monty	guest1

# %% [markdown]
# Now we can see what happens to our network when our Guest chooses 'A'.

# %%
observations = { 'guest' : 'A' }
beliefs = map( str, network.predict_proba( observations ) )
print("\n".join( "{}\t{}".format( state.name, belief ) for state, belief in zip( network.states, beliefs ) ))
# Out:
# guest	A
# prize	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "A" :0.3333333333333334,
#             "B" :0.3333333333333333,
#             "C" :0.3333333333333333
#         }
#     ],
#     "frozen" :false
# }
# monty	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "C" :0.49999999999999994,
#             "B" :0.49999999999999994,
#             "A" :0.0
#         }
#     ],
#     "frozen" :false
# }
# guest1	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "C" :0.25000000000000006,
#             "B" :0.25000000000000006,
#             "A" :0.49999999999999994
#         }
#     ],
#     "frozen" :false
# }

# %% [markdown]
# Now our host chooses 'B'. (note that prize goes to 66% if you switch)

# %%
observations = { 'guest' : 'A', 'monty' : 'B' }
beliefs = map( str, network.predict_proba( observations ) )
print("\n".join( "{}\t{}".format( state.name, belief ) for state, belief in zip( network.states, beliefs ) ))
# Out:
# guest	A
# prize	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "A" :0.3333333333333334,
#             "B" :0.0,
#             "C" :0.6666666666666664
#         }
#     ],
#     "frozen" :false
# }
# monty	B
# guest1	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "C" :0.49999999999999983,
#             "B" :0.0,
#             "A" :0.49999999999999983
#         }
#     ],
#     "frozen" :false
# }

# %% [markdown]
# We can also see what happens if our host simply chooses 'B'.

# %%
observations = { 'monty' : 'B' }
beliefs = map( str, network.predict_proba( observations ) )
print("\n".join( "{}\t{}".format( state.name, belief ) for state, belief in zip( network.states, beliefs ) ))
# Out:
# guest	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "A" :0.49999999999999983,
#             "B" :0.0,
#             "C" :0.49999999999999983
#         }
#     ],
#     "frozen" :false
# }
# prize	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "A" :0.49999999999999983,
#             "B" :0.0,
#             "C" :0.49999999999999983
#         }
#     ],
#     "frozen" :false
# }
# monty	B
# guest1	{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "C" :0.49999999999999983,
#             "B" :0.0,
#             "A" :0.49999999999999983
#         }
#     ],
#     "frozen" :false
# }
